# %%
from helpers import chunk_pdf

# Use this notebook to save PDFS to the data base
# (PDFs will also be saved to the files folder)
# Metadata can contain any fields of your choosing

url = "https://www.totnestowncouncil.gov.uk/wp-content/uploads/2021/05/Draft-Totnes-Neighbourhood-Plan-Reg-15-Revision-April-2021-FINAL.pdf"
metadata = {
    "category": "neighbourhood_plan",
    "lpa": "South Hams District Council",
    "council type": "District Council",
    "neighbourhood": "Totnes",
    "title": "Totnes Neighbourhood Plan 2019-2034",
    "url": url,
}

# file name is what the PDF will be saved as in the files folder
file_name = metadata["category"] + "-" + metadata["neighbourhood"] + ".pdf"
metadata["file"] = file_name

chunk_pdf(url, file_name, metadata)
# Out:
# PDF downloaded and saved as files/neighbourhood_plan-Totnes.pdf.
# PyMuPDF chunks created: 132 from files/neighbourhood_plan-Totnes.pdf
# Data successfully saved to files/pymupdf_chunks.csv
# Number of docs saving to db:  132
# Deleting any old temp files
# total pages:  67
# PDF split into segments of 10 pages in 'files/temp'
# Embedding files:  ['files/temp/1.pdf', 'files/temp/11.pdf', 'files/temp/21.pdf', 'files/temp/31.pdf', 'files/temp/41.pdf', 'files/temp/51.pdf', 'files/temp/61.pdf']
# splitting and embedding file: files/temp/1.pdf
#
# Sending files/temp/1.pdf to API
# files/temp/1.pdf analysed successfully
# Sherpa chunks created: 23 from files/temp/1.pdf
# 23 chunks added from files/temp/1.pdf
# splitting and embedding file: files/temp/11.pdf
#
# Sending files/temp/11.pdf to API
# files/temp/11.pdf analysed successfully
# Sherpa chunks created: 23 from files/temp/11.pdf
# 46 chunks added from files/temp/11.pdf
# splitting and embedding file: files/temp/21.pdf
#
# ...
