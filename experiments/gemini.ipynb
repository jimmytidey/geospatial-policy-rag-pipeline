# %%
from helpers import gemini_chunk, save_chunks_to_db
from langchain_core.documents import Document
import json
import uuid

metadata = {"category": "localplan", "lpa": "oxford_city_council"}


def read_file_in_sections(file_path, section_size=100):
    sections = []
    try:
        with open(file_path, "r") as file:
            while True:
                lines = []
                for _ in range(section_size):
                    line = file.readline()
                    if not line:
                        break
                    lines.append(line.strip())
                if not lines:
                    break
                sections.append("\n".join(lines))
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

    return sections


index = 0
# Example usage
file_path = "policy.txt"
sections = read_file_in_sections(file_path)
for i, section in enumerate(sections):
    docs = []

    json_chunk = gemini_chunk(section)
    print(json_chunk)
    chunks = json.loads(json_chunk)

    for chunk in chunks:
        local_metadata = dict(metadata)
        local_metadata["id"] = str(uuid.uuid4())
        local_metadata["index"] = index
        local_metadata["text"] = chunk["text"]
        local_metadata["policy"] = chunk["policy"]
        local_metadata["site"] = chunk["site"]
        local_metadata["sections"] = ">".join(chunk["headings"])

        print("---" * 30)

        print("Sections")
        print(local_metadata["sections"])

        print("Text")
        print(local_metadata["text"])

        print("---" * 30)

        doc = Document(
            page_content=local_metadata["text"],
            metadata=local_metadata,
        )

        docs.append(doc)

        index += 1

    save_chunks_to_db(docs)
# Out:
# [
#   {
#     "text": "This forward-thinking Local Plan aims to address the key issues facing Oxford’s residents and businesses. It endeavours to find the right balance to help us tackle the housing crisis and climate emergency, support our communities residents, ensure an attractive, resilient and healthy living and working environment, and to make Oxford’s successful economy work for all residents.",
#     "headings": [
#       "FOREWORD"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "The Local Plan sets out how we will tackle the existential threat of climate change. It will require all new homes and businesses in Oxford to be net zero-carbon and to operate without using fossil fuels. Resilience to climate important and policies require planting of trees and other green features, as well as flood-resistance measures such as sustainable drainage, in new developments. In addition, policies aim to preserve soil and air quality.",
#     "headings": [
#       "FOREWORD"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Oxford continues to suffer from a housing crisis. The plan identifies sites where 9,612 new homes will be built across Oxford by 2040. Policies allow homes to be built on all employment sites for the first time and encourage of poorly performing or poorly located employment sites to housing. Social housing continues to be prioritised. Within the 40% affordable housing required from larger developments, 80% must be social rent housing (the housing type), with the remaining 20% being other forms of affordable housing, such as ‘shared ownership’.",
#     "headings": [
#       "FOREWORD"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "It’s important that our successful economy works for everyone. Therefore, we require large developments to establish and deliver a plan to employ local people. The plan also aims to deliver affordable workspaces to help smaller businesses.",
#     "headings": [
#       "FOREWORD"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "The city should be an attractive and healthy place to live in, work in and visit. Major developers will need to submit a Health Impact Assessment, which sets out the ways the development will promote healthy lifestyles, such as with new walking routes, playing fields or parks. Parking standards keep new car parking spaces to a cycle parking. On top of this, the Local Plan will support and encourage vital community facilities and will continue to protect our district and local centres so that amenities people value and use on a daily basis are within a few minutes walk or cycle of their home.",
#     "headings": [
#       "FOREWORD"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "The Local Plan is the tool we will use to ensure Oxford is a fairer, greener and healthier city by 2040.",
#     "headings": [
#       "FOREWORD"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Where we are – Oxford’s Opportunities and Challenges",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Where we are going – Vision for Oxford in 2040",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Objectives and Strategy",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Oxford will be a healthy and inclusive city to live in",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy",
#       "Objectives and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Oxford will be a fair and prosperous city with a globally important role in learning, knowledge and innovation",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy",
#       "Objectives and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Oxford will be a green and biodiverse city that is resilient to climate change",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy",
#       "Objectives and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Oxford will be a city that utilises its resources with care, protects the air, water and soil and aims for net zero carbon",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy",
#       "Objectives and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Oxford will be a city that respects its heritage and fosters design of the highest quality",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy",
#       "Objectives and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Oxford will be a liveable city with strong communities and opportunities for all",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy",
#       "Objectives and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Overarching threads",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Policy S1: Spatial Strategy and Presumption in Favour of Sustainable Development",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy S2: Design Code and Guidance",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy S3: Infrastructure Delivery in New Development",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy S4: Plan Viability",
#     "headings": [
#       "CONTENTS",
#       "Vision and Strategy"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "A healthy, inclusive city to live in",
#     "headings": [
#       "CONTENTS"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Policy H1: Housing Requirement",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H2: Delivering affordable homes",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H3: Affordable housing contributions from new purpose-built student accommodation",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H4: Affordable housing contributions from self-contained older persons accommodation",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H5: Employer-linked affordable housing",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H6: Mix of dwelling sizes (number of bedrooms)",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H7: Development involving loss of dwellings",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H8: Houses in Multiple Occupation",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H9: Location of new student accommodation",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H10: Linking new academic facilities with the adequate provision of student accommodation",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H11: Homes for travelling communities",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H12: Homes for boat dwellers",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H13: Older Persons and Other Specialist Accommodation",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H14: Self-Build & Custom housebuilding",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H15: Hostels",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy H16: Boarding school accommodation",
#     "headings": [
#       "CONTENTS",
#       "A healthy, inclusive city to live in"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation",
#     "headings": [
#       "CONTENTS"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Policy E1: Employment Strategy",
#     "headings": [
#       "CONTENTS",
#       "A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy E2: Warehousing and Storage Uses",
#     "headings": [
#       "CONTENTS",
#       "A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy E3: Affordable Workspace",
#     "headings": [
#       "CONTENTS",
#       "A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy E4: Community Employment Plans",
#     "headings": [
#       "CONTENTS",
#       "A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy E5: Tourism and Short Stay Accommodation",
#     "headings": [
#       "CONTENTS",
#       "A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "A Green Biodiverse City that is Resilient to Climate Change",
#     "headings": [
#       "CONTENTS"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Policy G1: Protection of the Green Infrastructure",
#     "headings": [
#       "CONTENTS",
#       "A Green Biodiverse City that is Resilient to Climate Change"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy G2: Enhancement and provision of new Green and Blue features",
#     "headings": [
#       "CONTENTS",
#       "A Green Biodiverse City that is Resilient to Climate Change"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy G3: Provision of new Green and Blue features – Urban Greening Factor",
#     "headings": [
#       "CONTENTS",
#       "A Green Biodiverse City that is Resilient to Climate Change"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy G4: Delivering mandatory net gains in biodiversity",
#     "headings": [
#       "CONTENTS",
#       "A Green Biodiverse City that is Resilient to Climate Change"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy G5: Enhancing onsite biodiversity in Oxford",
#     "headings": [
#       "CONTENTS",
#       "A Green Biodiverse City that is Resilient to Climate Change"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy G6: Protecting Oxford’s biodiversity including the ecological network",
#     "headings": [
#       "CONTENTS",
#       "A Green Biodiverse City that is Resilient to Climate Change"
#     ],
#     "policy": true,
#     "site": false
#   }
# ]
# ------------------------------------------------------------------------------------------
# Sections
# FOREWORD
# Text
# This forward-thinking Local Plan aims to address the key issues facing Oxford’s residents and businesses. It endeavours to find the right balance to help us tackle the housing crisis and climate emergency, support our communities residents, ensure an attractive, resilient and healthy living and working environment, and to make Oxford’s successful economy work for all residents.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# FOREWORD
# Text
# The Local Plan sets out how we will tackle the existential threat of climate change. It will require all new homes and businesses in Oxford to be net zero-carbon and to operate without using fossil fuels. Resilience to climate important and policies require planting of trees and other green features, as well as flood-resistance measures such as sustainable drainage, in new developments. In addition, policies aim to preserve soil and air quality.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# FOREWORD
# Text
# Oxford continues to suffer from a housing crisis. The plan identifies sites where 9,612 new homes will be built across Oxford by 2040. Policies allow homes to be built on all employment sites for the first time and encourage of poorly performing or poorly located employment sites to housing. Social housing continues to be prioritised. Within the 40% affordable housing required from larger developments, 80% must be social rent housing (the housing type), with the remaining 20% being other forms of affordable housing, such as ‘shared ownership’.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# FOREWORD
# Text
# It’s important that our successful economy works for everyone. Therefore, we require large developments to establish and deliver a plan to employ local people. The plan also aims to deliver affordable workspaces to help smaller businesses.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# FOREWORD
# Text
# The city should be an attractive and healthy place to live in, work in and visit. Major developers will need to submit a Health Impact Assessment, which sets out the ways the development will promote healthy lifestyles, such as with new walking routes, playing fields or parks. Parking standards keep new car parking spaces to a cycle parking. On top of this, the Local Plan will support and encourage vital community facilities and will continue to protect our district and local centres so that amenities people value and use on a daily basis are within a few minutes walk or cycle of their home.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# FOREWORD
# Text
# The Local Plan is the tool we will use to ensure Oxford is a fairer, greener and healthier city by 2040.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy
# Text
# Where we are – Oxford’s Opportunities and Challenges
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy
# Text
# Where we are going – Vision for Oxford in 2040
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy
# Text
# Objectives and Strategy
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy>Objectives and Strategy
# Text
# Oxford will be a healthy and inclusive city to live in
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy>Objectives and Strategy
# Text
# Oxford will be a fair and prosperous city with a globally important role in learning, knowledge and innovation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy>Objectives and Strategy
# Text
# Oxford will be a green and biodiverse city that is resilient to climate change
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy>Objectives and Strategy
# Text
# Oxford will be a city that utilises its resources with care, protects the air, water and soil and aims for net zero carbon
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy>Objectives and Strategy
# Text
# Oxford will be a city that respects its heritage and fosters design of the highest quality
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy>Objectives and Strategy
# Text
# Oxford will be a liveable city with strong communities and opportunities for all
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy
# Text
# Overarching threads
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy
# Text
# Policy S1: Spatial Strategy and Presumption in Favour of Sustainable Development
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy
# Text
# Policy S2: Design Code and Guidance
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy
# Text
# Policy S3: Infrastructure Delivery in New Development
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>Vision and Strategy
# Text
# Policy S4: Plan Viability
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS
# Text
# A healthy, inclusive city to live in
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H1: Housing Requirement
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H2: Delivering affordable homes
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H3: Affordable housing contributions from new purpose-built student accommodation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H4: Affordable housing contributions from self-contained older persons accommodation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H5: Employer-linked affordable housing
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H6: Mix of dwelling sizes (number of bedrooms)
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H7: Development involving loss of dwellings
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H8: Houses in Multiple Occupation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H9: Location of new student accommodation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H10: Linking new academic facilities with the adequate provision of student accommodation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H11: Homes for travelling communities
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H12: Homes for boat dwellers
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H13: Older Persons and Other Specialist Accommodation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H14: Self-Build & Custom housebuilding
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H15: Hostels
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A healthy, inclusive city to live in
# Text
# Policy H16: Boarding school accommodation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS
# Text
# A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation
# Text
# Policy E1: Employment Strategy
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation
# Text
# Policy E2: Warehousing and Storage Uses
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation
# Text
# Policy E3: Affordable Workspace
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation
# Text
# Policy E4: Community Employment Plans
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Fair and Prosperous City with a Globally Important Role in Learning, Knowledge and Innovation
# Text
# Policy E5: Tourism and Short Stay Accommodation
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS
# Text
# A Green Biodiverse City that is Resilient to Climate Change
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Green Biodiverse City that is Resilient to Climate Change
# Text
# Policy G1: Protection of the Green Infrastructure
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Green Biodiverse City that is Resilient to Climate Change
# Text
# Policy G2: Enhancement and provision of new Green and Blue features
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Green Biodiverse City that is Resilient to Climate Change
# Text
# Policy G3: Provision of new Green and Blue features – Urban Greening Factor
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Green Biodiverse City that is Resilient to Climate Change
# Text
# Policy G4: Delivering mandatory net gains in biodiversity
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Green Biodiverse City that is Resilient to Climate Change
# Text
# Policy G5: Enhancing onsite biodiversity in Oxford
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# CONTENTS>A Green Biodiverse City that is Resilient to Climate Change
# Text
# Policy G6: Protecting Oxford’s biodiversity including the ecological network
# ------------------------------------------------------------------------------------------
# Number of docs saving to db:  50
# First doc:  page_content='This forward-thinking Local Plan aims to address the key issues facing Oxford’s residents and businesses. It endeavours to find the right balance to help us tackle the housing crisis and climate emergency, support our communities residents, ensure an attractive, resilient and healthy living and working environment, and to make Oxford’s successful economy work for all residents.' metadata={'category': 'localplan', 'lpa': 'oxford_city_council', 'id': 'b7c04caf-9621-4e39-8b24-d8ce23969592', 'index': 0, 'text': 'This forward-thinking Local Plan aims to address the key issues facing Oxford’s residents and businesses. It endeavours to find the right balance to help us tackle the housing crisis and climate emergency, support our communities residents, ensure an attractive, resilient and healthy living and working environment, and to make Oxford’s successful economy work for all residents.', 'policy': False, 'site': False, 'sections': 'FOREWORD'}
# /Users/jimmy/Projects/localplans-analysis/venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ['b7c04caf-9621-4e39-8b24-d8ce23969592', 'c1f4bb98-cd5f-4f79-a236-f82f8fc68e66', '94f33752-5e25-4adb-9888-b68664804e51', 'b26717f3-584c-4ac5-be40-9562fa2c5d7b', '07dfb34b-db9f-4547-b951-9247fcdc590f', 'e28f8c67-e91f-4a51-a05b-28dadfb0c8a6', '5452020e-83d6-4aae-92b7-f2e0d892bff3', 'e28de1e5-229b-4d68-831f-28a9cf9fa5df', 'c0c4e58e-d9e2-4c08-beb6-ef7ce875750f', '08a8066c-c6a0-404c-a9eb-88748c980062', 'fe076fa8-519d-4f64-a8b6-d40cfb28ac4f', '6bbe49c0-374c-4e27-a34c-8a41b82811ea', '5efd79c3-5f72-41d1-8632-cc2a68681110', 'e016aaf5-3335-4c4a-af61-896b97908bb9', 'e8f3bb51-2eff-4a41-9a51-fa696a1a5002', '38518b59-5760-4409-bb7d-8ac36e587562', '1a4e38a2-124e-486d-9c1f-607fa768b5b4', '7a953c09-196c-4ee6-9ff1-2ebf5cf98d79', '0267c92f-903c-4ce2-a3cc-6da38eb073bd', 'a64dc327-0d61-4ecc-9e76-f04d0b7f7bbc', 'e340b57c-70bb-45c0-8cd9-5fab3c38c947', 'acaa9a05-9e60-43fd-aa9e-ecebcc5202b8', '614c2ec6-5a77-4bc1-b98a-642d468efc72', '8c95bf05-1f3b-4243-afb0-e48a73e0cddb', '5a8a9000-0baf-4012-9751-7099870b0ef3', 'f1691a0b-86e9-432c-b656-079a3beddbfc', 'd8519c87-7614-406c-8f74-ed25e4b134f3', 'a06dc7e2-2bdf-4bc6-b271-f2295078f033', '2c41f2e1-aed5-4fef-9e8b-c4edc8cf66f5', 'ae31ec14-9777-4858-a0ed-95984bf38da2', '41e0f305-f876-4d52-855f-90a74266c123', '9e7834bd-a283-49f8-93ca-291a0d8ce491', 'f7cfac66-c44e-4218-9878-f4bd5c9737b1', 'f35346b7-525b-414a-ba4d-c87458310895', '2e17d0d5-7ec1-4c4b-9eb3-473d08afc455', 'aa66dd82-3a11-4611-bbaa-be4feed66b59', '9a6c1de1-4bfa-4b2d-b439-a8c83f5eedba', '9bd727a3-7f75-4fa7-94c5-d384a1cd0f0f', '50fe63b9-8c4b-440e-9d7c-ce830c6305fc', 'a0ac77cb-537e-4f48-8bc8-b4f28decb17b', 'e3600c95-c41b-4a16-8dd5-f3c7f64623d6', '036edfb8-a086-4124-87f2-db1429ac81a2', 'ccf6d5c4-de9a-4efa-836d-59de3d4ba68a', '862bec55-3a1d-417a-ab1a-63c81be18dab', '9e74dcaf-d717-4b89-af6c-107d22bdd56d', '84985d6b-dd14-4f05-a303-996a91b27c43', 'a2841dec-699b-45b8-9d72-b9065005f04e', 'f721ee69-f851-42e6-bb99-579cb9d088c8', '78735efa-8d5e-4bc4-8bb2-86bcb86697ab', '9a10e99c-7c22-49fa-b6b4-28916b65fb26']
# [
#   {
#     "text": "Policy G7: Flood risk and Flood Risk Assessments (FRAs)",
#     "headings": [
#       "Policy G7: Flood risk and Flood Risk Assessments (FRAs)"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy G8: Sustainable Drainage Systems (SuDS)",
#     "headings": [
#       "Policy G8: Sustainable Drainage Systems (SuDS)"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy G9: Resilient Design and Construction",
#     "headings": [
#       "Policy G9: Resilient Design and Construction"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "5. A City that utilises its resources with care, protects the air, water and soil and aims for net zero carbon",
#     "headings": [
#       "5. A City that utilises its resources with care, protects the air, water and soil and aims for net zero carbon"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Policy R1: Net Zero buildings in operation",
#     "headings": [
#       "Policy R1: Net Zero buildings in operation"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy R2: Embodied carbon in the construction process",
#     "headings": [
#       "Policy R2: Embodied carbon in the construction process"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy R3: Retro-fitting existing buildings",
#     "headings": [
#       "Policy R3: Retro-fitting existing buildings"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy R4: Air quality assessments and standards",
#     "headings": [
#       "Policy R4: Air quality assessments and standards"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy R5: Land contamination",
#     "headings": [
#       "Policy R5: Land contamination"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy R6: Soil quality",
#     "headings": [
#       "Policy R6: Soil quality"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy R7: Amenity and Environmental Health Impacts of Development",
#     "headings": [
#       "Policy R7: Amenity and Environmental Health Impacts of Development"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "6. A city of culture that respects its heritage and fosters design of the highest quality",
#     "headings": [
#       "6. A city of culture that respects its heritage and fosters design of the highest quality"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Policy HD1 Conservation Areas",
#     "headings": [
#       "Policy HD1 Conservation Areas"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD2 Listed Buildings",
#     "headings": [
#       "Policy HD2 Listed Buildings"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD3 Registered Parks and Gardens",
#     "headings": [
#       "Policy HD3 Registered Parks and Gardens"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD4 Scheduled Monuments",
#     "headings": [
#       "Policy HD4 Scheduled Monuments"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD5 Archaeology",
#     "headings": [
#       "Policy HD5 Archaeology"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD6 Non-designated Heritage Assets",
#     "headings": [
#       "Policy HD6 Non-designated Heritage Assets"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD7 Principles of High-Quality Design",
#     "headings": [
#       "Policy HD7 Principles of High-Quality Design"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD8 Using Context to Determine Appropriate Density",
#     "headings": [
#       "Policy HD8 Using Context to Determine Appropriate Density"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD9 Views and Building Heights",
#     "headings": [
#       "Policy HD9 Views and Building Heights"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD10 Health Impact Assessment",
#     "headings": [
#       "Policy HD10 Health Impact Assessment"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD11 Privacy, Daylight and Sunlight",
#     "headings": [
#       "Policy HD11 Privacy, Daylight and Sunlight"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD12 Internal Space Standards for Residential Development",
#     "headings": [
#       "Policy HD12 Internal Space Standards for Residential Development"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD13 Outdoor Amenity Space",
#     "headings": [
#       "Policy HD13 Outdoor Amenity Space"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD14 Accessible and Adaptable Homes",
#     "headings": [
#       "Policy HD14 Accessible and Adaptable Homes"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy HD15 Bin and Bike Stores and External Servicing Features",
#     "headings": [
#       "Policy HD15 Bin and Bike Stores and External Servicing Features"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "7. A Liveable City With Strong Communities and Opportunities for All",
#     "headings": [
#       "7. A Liveable City With Strong Communities and Opportunities for All"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "Policy C1: Town Centre Uses",
#     "headings": [
#       "Policy C1: Town Centre Uses"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy C2: Maintaining vibrant centres",
#     "headings": [
#       "Policy C2: Maintaining vibrant centres"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy C3: Protection, alteration and provision of local community facilities",
#     "headings": [
#       "Policy C3: Protection, alteration and provision of local community facilities"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy C4: Protection alteration and provision of learning and non-residential institutions",
#     "headings": [
#       "Policy C4: Protection alteration and provision of learning and non-residential institutions"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy C5: Protection, alteration and provision of cultural venues and visitor attractions",
#     "headings": [
#       "Policy C5: Protection, alteration and provision of cultural venues and visitor attractions"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy C6 : Transport Assessments, Travel Plans and Service and Delivery Plans",
#     "headings": [
#       "Policy C6 : Transport Assessments, Travel Plans and Service and Delivery Plans"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy C7: Bicycle Parking Design Standards",
#     "headings": [
#       "Policy C7: Bicycle Parking Design Standards"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy C8: Motor Vehicle Parking Design Standards",
#     "headings": [
#       "Policy C8: Motor Vehicle Parking Design Standards"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "Policy C9: Electric Vehicle Charging",
#     "headings": [
#       "Policy C9: Electric Vehicle Charging"
#     ],
#     "policy": true,
#     "site": false
#   },
#   {
#     "text": "8. Development Sites, Areas of Focus and Infrastructure",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure"
#     ],
#     "policy": false,
#     "site": false
#   },
#   {
#     "text": "North Infrastructure Area (including Northern Edge of Oxford Area of Focus and site allocation policies).",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "North Infrastructure Area (including Northern Edge of Oxford Area of Focus and site allocation policies)."
#     ],
#     "policy": false,
#     "site": true
#   },
#   {
#     "text": "Policy NEOAOF– Northern Edge of Oxford Area of Focus",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "North Infrastructure Area (including Northern Edge of Oxford Area of Focus and site allocation policies).",
#       "Policy NEOAOF– Northern Edge of Oxford Area of Focus"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPN1– Northern Gateway",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "North Infrastructure Area (including Northern Edge of Oxford Area of Focus and site allocation policies).",
#       "Policy SPN1– Northern Gateway"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPN2: Oxford University Press Sports Ground",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "North Infrastructure Area (including Northern Edge of Oxford Area of Focus and site allocation policies).",
#       "Policy SPN2: Oxford University Press Sports Ground"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "North Area site allocation policies outside of the Area of Focus",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "North Area site allocation policies outside of the Area of Focus"
#     ],
#     "policy": false,
#     "site": true
#   },
#   {
#     "text": "Policy SPN3: Diamond Place & Ewert House",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "North Area site allocation policies outside of the Area of Focus",
#       "Policy SPN3: Diamond Place & Ewert House"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)"
#     ],
#     "policy": false,
#     "site": true
#   },
#   {
#     "text": "Policy CBLLAOF: Cowley Branch Line and Littlemore Area of Focus",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#       "Policy CBLLAOF: Cowley Branch Line and Littlemore Area of Focus"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS1: ARC Oxford",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#       "Policy SPS1: ARC Oxford"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS2: Kassam Stadium and Ozone Leisure Park",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#       "Policy SPS2: Kassam Stadium and Ozone Leisure Park"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS3: Overflow Car Park, Kassam Stadium",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#       "Policy SPS3: Overflow Car Park, Kassam Stadium"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS4: MINI Plant Oxford",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#       "Policy SPS4: MINI Plant Oxford"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS5: Oxford Science Park",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#       "Policy SPS5: Oxford Science Park"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS6: Sandy Lane Recreation Ground",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#       "Policy SPS6: Sandy Lane Recreation Ground"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS7: Unipart",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South Infrastructure Area (including Cowley Branch Line and Littlemore Area of Focus)",
#       "Policy SPS7: Unipart"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "South area site allocation policies outside of the Area of Focus",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus"
#     ],
#     "policy": false,
#     "site": true
#   },
#   {
#     "text": "Policy SPS8: Bertie Place Recreation Ground",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus",
#       "Policy SPS8: Bertie Place Recreation Ground"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS9: Blackbird Leys Central Area",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus",
#       "Policy SPS9: Blackbird Leys Central Area"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS10: Knights Road",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus",
#       "Policy SPS10: Knights Road"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS11: Cowley Marsh Depot",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus",
#       "Policy SPS11: Cowley Marsh Depot"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS12: Templars Square",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus",
#       "Policy SPS12: Templars Square"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS13: Land at Meadow Lane",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus",
#       "Policy SPS13: Land at Meadow Lane"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS14: Former Iffley Mead Playing Field",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus",
#       "Policy SPS14: Former Iffley Mead Playing Field"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS15: Redbridge Paddock",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
#       "South area site allocation policies outside of the Area of Focus",
#       "Policy SPS15: Redbridge Paddock"
#     ],
#     "policy": true,
#     "site": true
#   },
#   {
#     "text": "Policy SPS16: Crescent Hall",
#     "headings": [
#       "8. Development Sites, Areas of Focus and Infrastructure",
# ...
#     ],
#     "policy": true,
#     "site": false
#   }
# ]
# ------------------------------------------------------------------------------------------
# Sections
# Liveable City
# Text
# on town centre uses (chapter 3), the protection of a network of green spaces across the city (chapter 4), as well as policies which address the provision of community facilities (chapter 7).Reducing inequalitiesAffordable housingMix of housingEmployment and skills plansAffordable workspacesProtect/provide green infrastructureHealth impact assessmentOverarching spatial strategyTown centre uses in district centresProtect community assetsProtect green infrastructureAreas of focus/infrastructure needsFigure 1.4: Key policies across the Local Plan which support the overarching thread of liveable cityLiveableCity19www.oxford.gov.uk/localplan2040OXFORDLOCALPLAN2040Spatial Strategy and Presumption in Favour of Sustainable Development1.35The policies in the Local Plan seek to ensure that new development across the city occurs in the right place. To guide development to the optimum location, development proposals must reflect the key principles which support the spatial strategy.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# Spatial Strategy and Presumption in Favour of Sustainable Development
# Text
# 1.36Policies in the Plan will focus on delivering sustainable growth for Oxford that meets the aims to deliver affordable housing, to support an inclusive economy, to ensure the protection of our green and blue networks and natural resources and support the city in moving towards being net zero carbon by 2040.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# Spatial Strategy and Presumption in Favour of Sustainable Development
# Text
# 1.37Development should create strong sustainable cohesive and inclusive communities to support Oxford as a liveable city which makes the most effective and efficient use of land and enable a larger number of residents to access services, facilities and jobs locally.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# Spatial Strategy and Presumption in Favour of Sustainable Development
# Text
# 1.38When determining development proposals, the Council will take a positive approach that reflects the presumption in favour of sustainable development contained in the National Planning Policy Framework (NPPF). The Council will work proactively with applicants with the aim of finding solutions that mean that proposals can be approved wherever possible, to secure development that improves the economic, social and environmental conditions in the city.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# Policy S1: Spatial Strategy and Presumption in Favour of Sustainable Development
# Text
# 20oxford local plan 2040 submission draftPolicy S1: Spatial Strategy and Presumption in Favour of Sustainable DevelopmentPlanning permission will be granted where development proposals accord with the policies of the Plan.The City Council, through its policies and decisions, will aim to positively pursue sustainable development and achieve sustainable growth in the delivery of homes, jobs and services to create a network of healthy, well-connected, high-quality areas where people want to live, play, learn and work in line with the vision and objectives of the Local Plan. To help achieve this it will aim to ensure development is located to:a)  ensure the continued strength and vibrancy district and local centres so they continue to attract people and support a range of facilities that meet people’s immediate needs conveniently within their local area;b)  ensure new development is focussed on areas with opportunities for sustainable travel links;c)  ensure activities that attract large numbers of people are centrally located in the city centre and district centres, so they are easy to reach by walking, cycling and public transport;d)  focus new employment development that supports Oxford’s national and international role in research and development on existing sites already in that use, prioritising housing elsewhere;e)  ensure new uses are in locations where they will not harm the amenity of existing neighbouring uses; andf)  prevent new development in locations where it would damage important blue and green infrastructure networks, public open space, and flood plain.
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Sections
# Policy S1: Spatial Strategy and Presumption in Favour of Sustainable Development
# Text
# When determining development proposals, the Council will take a positive approach that reflects the presumption in favour of sustainable development contained in the National Planning Policy Framework (NPPF). The Council will work proactively with applicants with the aim of finding solutions that mean that proposals can be approved wherever possible, to secure development that improves the economic, social and environmental conditions in the city.All new proposals for development must conform with the principles of securing sustainable development, which ensures that the city is ready for a net zero carbon future, natural resources and raw materials are used prudently and considerately, the air quality of the city is improved, and human health is safeguarded.
# ------------------------------------------------------------------------------------------
# Number of docs saving to db:  6
# First doc:  page_content='on town centre uses (chapter 3), the protection of a network of green spaces across the city (chapter 4), as well as policies which address the provision of community facilities (chapter 7).Reducing inequalitiesAffordable housingMix of housingEmployment and skills plansAffordable workspacesProtect/provide green infrastructureHealth impact assessmentOverarching spatial strategyTown centre uses in district centresProtect community assetsProtect green infrastructureAreas of focus/infrastructure needsFigure 1.4: Key policies across the Local Plan which support the overarching thread of liveable cityLiveableCity19www.oxford.gov.uk/localplan2040OXFORDLOCALPLAN2040Spatial Strategy and Presumption in Favour of Sustainable Development1.35The policies in the Local Plan seek to ensure that new development across the city occurs in the right place. To guide development to the optimum location, development proposals must reflect the key principles which support the spatial strategy.' metadata={'category': 'localplan', 'lpa': 'oxford_city_council', 'id': 'b2f228fc-1dd8-42d9-877b-cf072e4c179b', 'index': 224, 'text': 'on town centre uses (chapter 3), the protection of a network of green spaces across the city (chapter 4), as well as policies which address the provision of community facilities (chapter 7).Reducing inequalitiesAffordable housingMix of housingEmployment and skills plansAffordable workspacesProtect/provide green infrastructureHealth impact assessmentOverarching spatial strategyTown centre uses in district centresProtect community assetsProtect green infrastructureAreas of focus/infrastructure needsFigure 1.4: Key policies across the Local Plan which support the overarching thread of liveable cityLiveableCity19www.oxford.gov.uk/localplan2040OXFORDLOCALPLAN2040Spatial Strategy and Presumption in Favour of Sustainable Development1.35The policies in the Local Plan seek to ensure that new development across the city occurs in the right place. To guide development to the optimum location, development proposals must reflect the key principles which support the spatial strategy.', 'policy': False, 'site': False, 'sections': 'Liveable City'}
# ['b2f228fc-1dd8-42d9-877b-cf072e4c179b', '26b94c87-7b64-46ac-8038-83e10ffcbe05', 'd9c76df9-8436-414f-8f84-cd8a6ca17f23', 'c58c8d6f-1c8e-458f-b233-c9e9406d30b6', 'e4a28d58-3015-4c12-8f03-689353479e72', 'f6fdf152-64be-4ec0-aea3-88ca45ca7af3']
# [
# {
# "text": "Planning applications that accord with the policies in this Local Plan (and, where relevant, with policies in any neighbourhood plans adopted in the future) will be approved without delay, unless material considerations indicate otherwise. Where there are no policies relevant to the application or relevant policies are out of date at the time of making the decision, then the Council will grant permission unless material considerations indicate otherwise, considering whether:  g)	 the application of policies in the National Planning Policy Framework that protect areas or assets of particular importance provides a clear reason for refusing the development proposed; or  h)	 any adverse impacts of granting permission would significantly and demonstrably outweigh the benefits, when assessed against the policies in the National Planning Policy Framework taken as a whole.",
# "headings": [],
# "policy": false,
# "site": false
# },
# {
# "text": "Good design is a fundamental part of achieving many of the aims of the Plan. Good design is not just about creating aesthetically pleasing buildings. It is about placemaking, strengthening the connection between people and the places they share, promoting a sense of identity and people’s health and well-being.",
# "headings": [
# "Design Code and Guidance"
# ],
# "policy": false,
# "site": false
# },
# {
# "text": "Oxford’s heritage is a unique and irreplaceable resource, which has a fundamental role in shaping the city’s character and cultural offer. The City Council is committed to preparing, reviewing, and adopting (as appropriate) conservation area appraisal and management plans, as well as other evidence base documents to help further understanding of the significance and benefits of our heritage assets.",
# "headings": [
# "Design Code and Guidance"
# ],
# "policy": false,
# "site": false
# },
# {
# "text": "Good design will also need to support the protection and enhancement of our natural environment for the many benefits it provides. This means ensuring that the design of the built environment factors in spaces for nature and wildlife, as well as green features which perform multiple functions that support people’s wellbeing, such as providing spaces to socialise and get closer to nature, promoting cooling during hot weather and flood retention during heavy rainfall. Fundamental to good design is also the transition to net zero carbon development. This means encouraging a range of measures that secure energy efficiency and energy generation so that our buildings operate without adding to greenhouse gas emissions, are constructed in ways that use natural resources prudently and enable future occupants to travel and live in ways that can help them to reduce their carbon footprint.",
# "headings": [
# "Design Code and Guidance"
# ],
# "policy": false,
# "site": false
# },
# {
# "text": "Design should be a collaborative process. The community has been consulted during the creation of this local plan, including through a workshop led by Design South East that has informed the development principles in the Marston Road and Old Road Area of Focus. Supporting documents will be developed with community collaboration where these would be helpful. The Botley Retail Park Development Brief 2022 and the West End and Osney Mead Supplementary Planning Document (SPD) set out guidance for these two areas.",
# "headings": [
# "Design Code and Guidance"
# ],
# "policy": false,
# "site": false
# },
# {
# "text": "The design checklist set out in Appendix 1.1 should be used to inform design and ensure that a comprehensive approach is taken from the outset, which includes consideration of the relevant context including heritage, promotion of healthy lifestyles, and protection of the natural environment. For Areas of Focus, the City Centre and District Centres, and other areas with more detailed guidance, proposals should refer to and align with the design principles set out in the Local Plan or in supporting documents such as the West End and Osney Mead Supplementary Planning Document and the Botley Road Retail Park Development Brief 2022. The City Council will be proactive in producing additional local design codes or guidance when a need arises (such as the Botley Design Guide), involving the local community and landowners, and will support neighbourhood planning groups who wish to produce design guidance for their areas.",
# "headings": [
# "Policy S2: Design Code and Guidance"
# ],
# "policy": true,
# "site": false
# },
# {
# "text": "In recognition of the significance of Oxford’s heritage, and as part of its positive approach to the historic environment, in addition to fulfilling its statutory duties, the Council will: a)	 identify, conserve and enhance local heritage assets b)	 take a proactive approach to the protection, promotion and interpretation of the city’s archaeological remains c)	 support the conservation and appreciation of key characteristics of the wider townscape and landscape d)	 take a positive strategy towards assets that are considered at risk.",
# "headings": [
# "Policy S2: Design Code and Guidance"
# ],
# "policy": true,
# "site": false
# },
# {
# "text": "To deliver the Local Plan vision for 2040, the spatial strategy and plan objectives, the provision of infrastructure will need to be funded and delivered in a timely manner to support development. It is important to ensure that roads, local services and facilities can cope with the increased demand resulting from development proposed in the Plan.",
# "headings": [
# "Infrastructure Delivery in New Developments"
# ],
# "policy": false,
# "site": false
# }
# ]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 39
#      37 json_chunk = gemini_chunk(section)
#      38 print(json_chunk)
# ---> 39 chunks = json.loads(json_chunk)
#      41 for chunk in chunks:
#      42     local_metadata = dict(metadata)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Invalid control character at: line 3 column 493 (char 496)
