# %%
import os
from PyPDF2 import PdfReader


def read_pdfs_in_folder(folder_path):
    # Ensure the folder path is valid
    if not os.path.isdir(folder_path):
        raise ValueError(f"The folder path {folder_path} is not valid.")

    # Create the 'txt' directory if it doesn't exist
    txt_folder_path = os.path.join(folder_path, "txt")
    if not os.path.exists(txt_folder_path):
        os.makedirs(txt_folder_path)

    # Iterate through all the files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is a PDF
        if filename.endswith(".pdf"):
            file_path = os.path.join(folder_path, filename)
            try:
                with open(file_path, "rb") as file:
                    reader = PdfReader(file)

                    # Extract text from the PDF
                    pdf_text = ""
                    for page in reader.pages:
                        pdf_text += page.extract_text() if page.extract_text() else ""

                    # Write the extracted text to a text file
                    txt_filename = os.path.splitext(filename)[0] + ".txt"
                    txt_file_path = os.path.join(txt_folder_path, txt_filename)
                    with open(txt_file_path, "w", encoding="utf-8") as txt_file:
                        txt_file.write(pdf_text)

                    print(
                        f"Extracted text from {filename} and wrote to {txt_file_path}"
                    )

            except Exception as e:
                print(f"Failed to read {filename} due to {e}")


# Example usage
folder_path = "files"
read_pdfs_in_folder(folder_path)
# Out:
# Extracted text from neighbourhood_plan-Cossington.pdf and wrote to files/txt/neighbourhood_plan-Cossington.txt
# Extracted text from neighbourhood_plan-Addingham.pdf and wrote to files/txt/neighbourhood_plan-Addingham.txt
# Extracted text from neighbourhood_plan-Ab Kettleby Parish.pdf and wrote to files/txt/neighbourhood_plan-Ab Kettleby Parish.txt
# Extracted text from neighbourhood_plan-Sawtry.pdf and wrote to files/txt/neighbourhood_plan-Sawtry.txt
# Extracted text from neighbourhood_plan-Totnes.pdf and wrote to files/txt/neighbourhood_plan-Totnes.txt
# Extracted text from neighbourhood_plan-Aberford.pdf and wrote to files/txt/neighbourhood_plan-Aberford.txt
# Extracted text from neighbourhood_plan-Cleobury Mortimer.pdf and wrote to files/txt/neighbourhood_plan-Cleobury Mortimer.txt
# Extracted text from neighbourhood_plan-Walsham le Willows.pdf and wrote to files/txt/neighbourhood_plan-Walsham le Willows.txt
# Extracted text from neighbourhood_plan-Nether Whitacre.pdf and wrote to files/txt/neighbourhood_plan-Nether Whitacre.txt
# Extracted text from neighbourhood_plan-West Wittering.pdf and wrote to files/txt/neighbourhood_plan-West Wittering.txt
# Extracted text from neighbourhood_plan-Adel.pdf and wrote to files/txt/neighbourhood_plan-Adel.txt
# Extracted text from neighbourhood_plan-Elmswell.pdf and wrote to files/txt/neighbourhood_plan-Elmswell.txt
# Extracted text from neighbourhood_plan-Acle.pdf and wrote to files/txt/neighbourhood_plan-Acle.txt
# Extracted text from neighbourhood_plan-Abberley.pdf and wrote to files/txt/neighbourhood_plan-Abberley.txt
# Extracted text from neighbourhood_plan-Winkfield.pdf and wrote to files/txt/neighbourhood_plan-Winkfield.txt
# Extracted text from neighbourhood_plan-Corby Glen.pdf and wrote to files/txt/neighbourhood_plan-Corby Glen.txt
# Extracted text from neighbourhood_plan-Whaley Bridge.pdf and wrote to files/txt/neighbourhood_plan-Whaley Bridge.txt
# Extracted text from neighbourhood_plan-Alcester.pdf and wrote to files/txt/neighbourhood_plan-Alcester.txt
# Extracted text from neighbourhood_plan-Abbots Langley.pdf and wrote to files/txt/neighbourhood_plan-Abbots Langley.txt
# Extracted text from neighbourhood_plan-Strensall & Towthorpe.pdf and wrote to files/txt/neighbourhood_plan-Strensall & Towthorpe.txt
# Failed to read neighbourhood_plan-Winchfield.pdf due to PyCryptodome is required for AES algorithm
# Extracted text from neighbourhood_plan-Acton.pdf and wrote to files/txt/neighbourhood_plan-Acton.txt
# Extracted text from neighbourhood_plan-The Three Parishes.pdf and wrote to files/txt/neighbourhood_plan-The Three Parishes.txt
# Extracted text from neighbourhood_plan-Alfold.pdf and wrote to files/txt/neighbourhood_plan-Alfold.txt
# Extracted text from neighbourhood_plan-Fulbourn.pdf and wrote to files/txt/neighbourhood_plan-Fulbourn.txt

# %%
import os
from datetime import datetime
import ast

all_responses = []
for filename in os.listdir("files/txt"):
    # Check if the file is a PDF
    if filename.endswith(".txt"):
        file_path = os.path.join("files/txt/", filename)
        try:
            with open(file_path, "rb") as file:
                # print file name

                print(f"Reading {filename}")
                print(f"Gemini query starts at {datetime.now()}")

                genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
                model = genai.GenerativeModel("gemini-1.5-flash")

                prompt = "Please return a list of 20 main topics discussed below. Return the list as a machine readable JSON list (only valid json returned). Please do not include ```json or ``` or newline characters.\n\n"
                with open(file_path, "r") as file:
                    text = file.read()
                    prompt += text

                response = model.generate_content(prompt)

                print(f"Gemini query complete at {datetime.now()}")

                all_responses.append(ast.literal_eval(response.text))

                print(response.text)

        except Exception as e:
            print(f"Failed to read {filename} due to {e}")
# Out:
# Reading neighbourhood_plan-West Wittering.txt
# Gemini query starts at 2024-06-11 01:20:43.454221
# Gemini query complete at 2024-06-11 01:20:49.447115
# ["Introduction", "National and Local Planning Context", "The Parish of West Wittering", "Vision & Objectives", "Policies & Proposals", "Non-Statutory Community Aspirations", "Delivery Plan", "Heritage", "Community Facilities", "Public Rights of Way and Quiet Lanes", "Housing", "Coastal Enhancements", "Biodiversity, Geodiversity and Mitigating the Impacts of Climate Change", "Economic Development", "Visitor Accommodation and Facilities", "Lighting", "Utility Infrastructure", "Design", "Preventing Coalescence", "Retail Facilities"]
# Reading neighbourhood_plan-Walsham le Willows.txt
# Gemini query starts at 2024-06-11 01:20:49.447599
# Gemini query complete at 2024-06-11 01:20:57.434265
# ["Introduction", "National and local strategic planning policy context", "Walsham le Willows parish", "How the Plan was prepared", "Vision, objectives and policies", "Built Environment and Design", "Housing", "Community and Infrastructure", "Transport and Accessibility", "Natural and Historic Environment", "Economy", "Projects and Community Infrastructure Levy (CIL) funding", "Implementation and monitoring", "Challenges for Walsham le Willows", "Pre-Submission Consultation – Regulation 14", "Neighbourhood Plan Vision for 2037", "Neighbourhood Plan objectives", "Neighbourhood Plan policies", "Gardens and amenity", "Sustainable and environmental design features"]
# Reading neighbourhood_plan-Nether Whitacre.txt
# Gemini query starts at 2024-06-11 01:20:57.436009
# Gemini query complete at 2024-06-11 01:21:02.862196
# {"main_topics": ["Foreword", "Vision of the Parish", "Why a Neighbourhood Plan?", "Steering Group", "Development Boundary Policy", "Housing Policies", "Transport Policy", "Local Economy Policies", "Environmental Policies", "Green Spaces", "Community Policies", "Appendix 1: Data Collection", "Appendix 2: Further Research Supporting HP3", "Appendix 3: History and Character Attractions in the Parish", "Appendix 4: Sites of Special Interest", "Appendix 5: Areas of Influence Connected to the Parish", "Parking", "Flood Defenses", "Visitor Accommodation", "Local Economy"]}
# Reading neighbourhood_plan-Abberley.txt
# Gemini query starts at 2024-06-11 01:21:02.864219
# Gemini query complete at 2024-06-11 01:21:05.832550
# ["SETTING THE SCENE", "Introduction", "Format of the Neighbourhood Development Plan", "National and local planning policy context", "ABBERLEY NEIGHBOURHOOD AREA", "The community of Abberley", "Environment", "Economy", "Key issues", "VISION AND OBJECTIVES", "Vision", "Objectives", "Objectives for the community", "Objectives for the natural environment", "Objectives for the built environment", "Objectives for the economy", "SUSTAINABLE DEVELOPMENT", "SOCIAL AND COMMUNITY", "Type of new housing", "Criteria for development of Land at The Orchard"]
# Reading neighbourhood_plan-Elmswell.txt
# Gemini query starts at 2024-06-11 01:21:05.834764
# Gemini query complete at 2024-06-11 01:21:15.661826
# ["Introduction", "National and local strategic planning policy context", "Walsham le Willows Parish", "How the Plan was prepared", "Vision, objectives and policies", "Built Environment and Design", "Housing", "Community and Infrastructure", "Transport and Accessibility", "Natural and Historic Environment", "Economy", "Projects and Community Infrastructure Levy (CIL) funding", "Implementation and monitoring", "Local Green Space justification", "Non-designated Heritage Assets justification", "Glossary", "Housing Needs Assessment", "Design Guidance and Codes", "Built Environment and Design Policies", "Housing Policies"]
# Reading neighbourhood_plan-Acle.txt
# Gemini query starts at 2024-06-11 01:21:15.663159
# Gemini query complete at 2024-06-11 01:21:18.324028
# Failed to read neighbourhood_plan-Acle.txt due to The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Reading neighbourhood_plan-Adel.txt
# Gemini query starts at 2024-06-11 01:21:18.325259
# Gemini query complete at 2024-06-11 01:21:22.310915
# ["Foreword", "Introduction", "The Neighbourhood Area", "Policy Context", "Summary of Opportunities", "Vision and Objectives", "Policies", "Natural and Built Heritage Policies", "Character and Design Policies", "Housing Policies", "Community Facilities and Green Space Policies", "Retail and Business Policies", "Highways and Traffic Policies", "Implementation", "List of Appendices", "List of Figures", "Neighbourhood Plans form part of the planning system", "About this Document", "About Neighbourhood Plans", "Neighbourhood Plan Preparation Process"]
# Reading neighbourhood_plan-Addingham.txt
# Gemini query starts at 2024-06-11 01:21:22.313439
# Gemini query complete at 2024-06-11 01:21:25.902745
# ["Addingham", "Neighbourhood", "Development Plan", "Vision Statement", "Contents", "Foreword", "Introduction", "Key Issues", "Vision and Objectives", "City of Bradford Metropolitan District", "Strategic Planning Policy", "Policies and Proposals", "Housing Needs", "Natural Environment", "Climate Change", "Business and Employment", "Transport, Traffic and Parking", "Local Green Spaces", "Protecting and Enhancing Recreation Facilities", "Green Infrastructure", "Responding to Climate Change", "Monitoring and Review", "Policies Map", "Appendix 1", "Non-designated heritage assets"]
# Reading neighbourhood_plan-Ab Kettleby Parish.txt
# Gemini query starts at 2024-06-11 01:21:25.904256
# Gemini query complete at 2024-06-11 01:21:29.179661
# ["Introduction", "How the Neighbourhood Plan fits into the planning system", "The Plan, its vision, objectives and what we want it to achieve", "How the Plan was prepared", "Our Parish", "Meeting the requirement for sustainable development", "Neighbourhood Plan Policies", "Strategy", "Housing", "Environment", "Community Facilities and amenities", "Transport", "Businesses and employment", "Support for existing businesses and employment", "Support for new businesses and employment", "Home working", "Farm diversification", "Tourism", "Broadband speeds and mobile phone signals", "Monitoring and Review"]
# Reading neighbourhood_plan-Cossington.txt
# Gemini query starts at 2024-06-11 01:21:29.181561
# Gemini query complete at 2024-06-11 01:21:36.634437
# ["Introduction", "How the Plan was prepared", "How the NP fits into the planning system", "The NP, its purpose and what we want it to achieve", "Sustainable Development", "About Cossington", "Housing and the Built Environment", "Residential Allocation", "Settlement Boundary", "Housing Mix", "Affordable Housing", "Windfall sites", "Design and the built environment", "The Natural, Historical and Social Environment", "Landscape, geology and setting", "Quarrying", "Historical environment", "Natural environment", "Existing environmental designations", "Environmental inventory"]
# Reading neighbourhood_plan-Cleobury Mortimer.txt
# Gemini query starts at 2024-06-11 01:21:36.636365
# Gemini query complete at 2024-06-11 01:21:41.783653
# ["Introduction", "Background", "Status of the Neighbourhood Plan", "Plan of the Neighbourhood Area", "Context", "Strategy for Sustainable Growth", "Our Neighbourhood Area", "Vision", "Aims", "Policies", "Overview", "Employment and Housing", "Town Centre and Economy", "Community Facilities", "Residential Development", "Heritage -Led Regeneration and Conservation", "Heritage", "Peak Forest Canal", "Transhipment Shed and Canal Basin", "Environment and Climate Change"]
# Reading neighbourhood_plan-Totnes.txt
# Gemini query starts at 2024-06-11 01:21:41.785667
# Gemini query complete at 2024-06-11 01:21:44.846809
# ["Introduction", "What is a NP and why is it important to the Totnes community?", "What area does the NP cover?", "How does the NP relate to other plans and what period does it cover?", "How has the NP been prepared?", "Are there any limits on the NP?", "How will the plan be used and who is it for?", "Vision and Objectives", "Vision", "Objectives", "Local Identity", "Health and Wellbeing", "What Makes Totnes Special?", "Environment", "Sustainable Development and the Settlement Boundary", "Development and Design", "Historic and Built Character", "Landscape Setting of Totnes", "The River Dart", "Enhancing Local Environmental Capacity"]
# Reading neighbourhood_plan-Sawtry.txt
# Gemini query starts at 2024-06-11 01:21:44.848117
# Gemini query complete at 2024-06-11 01:21:51.546744
# ["Sawtry Village Neighbourhood Plan", "Neighbourhood Planning", "Purpose of Neighbourhood Planning", "Benefits of Neighbourhood Planning", "Legislative Background", "Village Scene", "Contemporary Challenges", "Sawtry History", "Local Shops", "Heritage Assets", "Transport", "Population and Employment", "Dwelling Stock", "Residential Development", "Education", "Religious Observance", "Medical and Dental Services", "Community Services", "Sports and Leisure Facilities", "Surface Water"]
# Reading neighbourhood_plan-Aberford.txt
# Gemini query starts at 2024-06-11 01:21:51.547295
# Gemini query complete at 2024-06-11 01:22:01.849708
# ["Introduction", "The Neighbourhood Plan Area", "The Neighbourhood Plan Preparation Process", "The Vision & Aims for Aberford", "The Plan Policies and Community Actions", "Green Environment", "Special Landscape Areas", "Local Green Infrastructure", "Local Green Space", "Local Green Space Enhancement", "Community Actions", "Heritage Assets", "Development Affecting Aberford Conservation Area", "Built Heritage Assets", "Community Actions", "Community Facilities and Services", "Protection and Enhancement of Community Facilities", "Provision of New Community Facilities", "Aberford Village Hall Site", "Coal Staithes Site", "Community Actions", "Housing", "New Housing Development - Key Guiding Principles", "Development on Non-Allocated Sites", "Housing Mix", "Community Actions", "Monitoring, Review, Implementation", "Monitoring, Review and Strategic Delivery", "Community Infrastructure Levy in the Parish", "Community Actions and Approaches", "Project Delivery Plan", "Appendices", "Local Green Infrastructure", "Candidate Local Green Space Sites Assessment", "Key Conservation Area Views", "Non-Designated Heritage Assets", "Community Facilities", "Neighbourhood Plan Map - Large Scale Maps"]
# Reading neighbourhood_plan-Strensall & Towthorpe.txt
# Gemini query starts at 2024-06-11 01:22:01.853299
# Gemini query complete at 2024-06-11 01:22:44.654969
# ["INTRODUCTION", "STATUS OF THE VILLAGE DESIGN STATEMENT", "STRENSALL WITH TOWTHORPE NEIGHBOURHOOD PLAN", "PREPARATION PROCESS", "NEXT STAGE OF THE PROCESS", "HISTORY OF STRENSALL WITH TOWTHORPE", "THE HISTORY OF THE VILLAGE", "THE LAYOUT OF THE VILLAGE", "DEMOGRAPHIC PROFILE", "POLICY CONTEXT FOR THE NEIGHBOURHOOD PLAN", "NATIONAL PLANNING POLICY FRAMEWORK", "LOCAL PLANNING POLICY", "GREEN BELT", "DEVELOPMENT ALLOCATIONS", "OPEN SPACE AND GREEN INFRASTRUCTURE", "CONSERVATION AREAS", "LISTED BUILDINGS", "ECOLOGY AND NATURE CONSERVATION", "AIMS AND OBJECTIVES OF THE PLAN", "AIMS OF THE PLAN", "OBJECTIVES OF THE PLAN", "NEIGHBOURHOOD PLAN POLICIES", "CAR PARKING", "COMMUNITY FACILITIES AND OPEN SPACE", "DESIGN AND HERITAGE", "DEVELOPMENT GUIDANCE", "AFFORDABLE HOUSING", "COMMUNITY ACTIONS", "HIGHWAYS IMPROVEMENTS", "DESIGNATION OF PUBLIC RIGHTS OF WAY", "DESIGNATION OF ASSETS OF COMMUNITY VALUE", "AFFORDABLE HOUSING - LOCAL CONNECTION APPROACH", "COMMUNITY INFRASTRUCTURE LEVY", "CAR PARKING SURVEY OF STRENSALL", "LOCAL GREEN SPACE DESIGNATION", "LOCAL CONNECTIONS CRITERIA FOR AFFORDABLE HOUSING", "STRENSALL WITH TOWTHORPE CHARACTER APPRAISAL", "BUILT FORM", "MATERIALS", "ARCHITECTURAL FEATURES", "STRENSALL WITH TOWTHORPE VILLAGE DESIGN STATEMENT"]
# Reading neighbourhood_plan-Fulbourn.txt
# Gemini query starts at 2024-06-11 01:22:44.658389
# Gemini query complete at 2024-06-11 01:22:53.557885
# ["Introduction", "Why have a Neighbourhood Plan?", "Credibility through Evidence", "Plan Preparation Process", "The Parish Plan", "The Plan Area", "Planning Policy Framework", "National Planning Policy Framework (2021)", "South Cambridgeshire Local Plan (2018)", "Emerging Greater Cambridge Local Plan", "Fulbourn Village Design Guide SPD (2020)", "Other Relevant Pla nning Documents", "Local Context", "A Brief History of the Village", "Recent Growth and Development", "Business and Employment", "Community Facilities", "Landscape Setting and Relationship with the Countryside", "Local Character", "Natural Greenspace and Biodiversity"]
# Reading neighbourhood_plan-Acton.txt
# Gemini query starts at 2024-06-11 01:22:53.559097
# Gemini query complete at 2024-06-11 01:23:04.927210
# ["Foreword by the Steering Group", "Introduction", "Acton", "National and Local Context", "How the Plan was Prepared", "Vision and Objectives", "Policies", "Housing", "Environment", "Access and Community", "Business", "Implementation and Monitoring", "Appendix A: Neighbourhood Plan Steering Group Members", "Appendix B: Non-Designated Heritage Assets Justification", "Appendix C: Local Green Space Assessments", "Appendix D: Glossary", "Appendix E: Policies Maps - Inset Map 1: Acton Village Map", "Inset Map 2: Newman’s Green and Inset Map 3: Bull Lane Employment Area", "Inset Map 4: Whole Parish Policies Map", "Potential Community Projects"]
# Reading neighbourhood_plan-The Three Parishes.txt
# Gemini query starts at 2024-06-11 01:23:04.929840
# Gemini query complete at 2024-06-11 01:23:08.611295
# ["Introduction and Stages", "Setting the Context", "Description of the Three Parishes Neighbourhood Area", "Housing", "Heritage", "Landscape and Natural Environment", "Why are we preparing a Neighbourhood Plan?", "What is a Neighbourhood Plan?", "Submission of Application to Designate the Neighbourhood Area", "Process to Date", "National and Local Planning Policy", "National Planning Policy Framework", "Shropshire Local Plan", "Emerging Shropshire Local Plan", "Evidence Base", "Consultations", "Technical Evidence", "SEA and HRA", "Vision and Objectives", "The Vision of the Neighbourhood Plan", "Objectives", "Policies", "Housing and Design", "Employment and Business", "Natural Environment", "Movement and Connection", "Built Environment and Heritage", "Community Facilities", "Monitoring and Review", "Process of Preparing a Neighbourhood Plan", "National Heritage List", "Neighbourhood Plan Boundary", "Policy Monitoring"]
#
# Reading neighbourhood_plan-Alfold.txt
# Gemini query starts at 2024-06-11 01:23:08.613421
# Gemini query complete at 2024-06-11 01:23:18.442099
# ["Contents", "Schedule of Policies", "Foreword", "Introduction, Context and Vision", "Consultation, Aspirations, Vision and Objectives", "Alfold – Parish and Community", "Planning Policy Context", "Development Theme", "Housing", "Housing Need ( Type and Mix )", "Retirement Housing Provision", "Housing Types", "Affordable Housing  and its allocation", "Business and Tourism", "Retail", "Employment", "Tourism", "Countryside & Environment Theme", "Green Spaces", "Dark Skies", "Protecting Settlement Character and Distinctiveness", "Biodiversity", "Wey & Arun Canal", "Community Theme", "Health, Wellbeing and Leisure", "Social isolation", "Education", "Infrastructure Theme", "Traffic and Transport", "Broadband and mobile phone coverage", "Digital Connectivity", "Other Infrastructure", "Delivery and Review", "Community Infrastructure Projects", "Implementation, Monitoring and Review", "Glossary"]
# Reading neighbourhood_plan-Whaley Bridge.txt
# Gemini query starts at 2024-06-11 01:23:18.444853
# Gemini query complete at 2024-06-11 01:23:23.971293
# ["Introduction", "Background", "Status of the Neighbourhood Plan", "Plan of the Neighbourhood Area", "Context", "Strategy for Sustainable Growth", "Our Neighbourhood Area", "Vision", "Aims", "Policies", "Overview", "Employment and Housing", "WB-G1 Town Centre and Economy", "WB-G2 Community Facilities", "WB-G3 Residential Development", "Heritage -Led Regeneration and Conservation", "WB-H1 Heritage", "WB-H2 Peak Forest Canal", "WB-H3 Transhipment Shed and Canal Basin", "Environment and Climate Change"]
#
# Reading neighbourhood_plan-Winkfield.txt
# Gemini query starts at 2024-06-11 01:23:23.972612
# Gemini query complete at 2024-06-11 01:23:36.259454
# ["Introduction and Background", "The Neighbourhood Area", "Planning Policy Context", "Community Views on Planning Issues", "Vision and Objectives", "Spatial Strategy", "Design and Character", "Housing", "Community", "Employment", "Green Infrastructure/Environment", "Promoting Sustainable Transport", "Implementation", "Glossary and Abbreviations", "Local Green Space Maps", "Schedule of Evidence", "Consultation Statement", "Basic Conditions Statement", "SEA", "HRA"]
# Reading neighbourhood_plan-Corby Glen.txt
# Gemini query starts at 2024-06-11 01:23:36.260774
# Gemini query complete at 2024-06-11 01:23:39.843608
# ["Explanation of planning process and the role of Neighbourhood Plans", "Description of the area and community covered by this Neighbourhood Plan", "Methods of evidence gathering for the Neighbourhood Plan", "Emerging themes and issues arising from consultation with the community", "Vision and objectives", "List of Planning Policies", "Planning Policies", "Community Aspirations", "Monitoring, Review and Implementation"]
# Reading neighbourhood_plan-Abbots Langley.txt
# Gemini query starts at 2024-06-11 01:23:39.845178
# Gemini query complete at 2024-06-11 01:23:47.014834
# ["Executive Summary", "Introduction", "National policy", "Local Policy", "Key stages on how the Plan has been prepared", "Sustainability of the Neighbourhood Plan", "An Introduction to Abbots Langley Parish", "Vision and Objectives", "Spatial Strategy", "Housing", "Local Character, Heritage and Design", "Local Economy", "Natural Environment", "Leisure and Community", "Transport and Movement", "Implementation and Plan Review", "Infrastructure Improvements and Provision", "Policies Maps", "Non-Policy Community Actions", "Glossary"]
# Reading neighbourhood_plan-Alcester.txt
# Gemini query starts at 2024-06-11 01:23:47.015446
# Gemini query complete at 2024-06-11 01:23:53.872304
# ["Introduction", "Historical Information", "Alcester Today", "Key Issues", "Vision Statement", "Objectives and Policies", "Housing and the Built Environment", "Economy", "Transport and Infrastructure", "Community, Leisure and Well-being", "Natural Environment", "Projects", "CIL and Project Funding", "Appendices", "Glossary", "References", "Housing Commitments and Completions since 2011 - Alcester Parish", "Local Green Spaces", "Valued Landscapes", "Flood Map"]

# %%
print(all_responses)
# Out:
# [['Introduction', 'National and Local Planning Context', 'The Parish of West Wittering', 'Vision & Objectives', 'Policies & Proposals', 'Non-Statutory Community Aspirations', 'Delivery Plan', 'Heritage', 'Community Facilities', 'Public Rights of Way and Quiet Lanes', 'Housing', 'Coastal Enhancements', 'Biodiversity, Geodiversity and Mitigating the Impacts of Climate Change', 'Economic Development', 'Visitor Accommodation and Facilities', 'Lighting', 'Utility Infrastructure', 'Design', 'Preventing Coalescence', 'Retail Facilities'], ['Introduction', 'National and local strategic planning policy context', 'Walsham le Willows parish', 'How the Plan was prepared', 'Vision, objectives and policies', 'Built Environment and Design', 'Housing', 'Community and Infrastructure', 'Transport and Accessibility', 'Natural and Historic Environment', 'Economy', 'Projects and Community Infrastructure Levy (CIL) funding', 'Implementation and monitoring', 'Challenges for Walsham le Willows', 'Pre-Submission Consultation – Regulation 14', 'Neighbourhood Plan Vision for 2037', 'Neighbourhood Plan objectives', 'Neighbourhood Plan policies', 'Gardens and amenity', 'Sustainable and environmental design features'], {'main_topics': ['Foreword', 'Vision of the Parish', 'Why a Neighbourhood Plan?', 'Steering Group', 'Development Boundary Policy', 'Housing Policies', 'Transport Policy', 'Local Economy Policies', 'Environmental Policies', 'Green Spaces', 'Community Policies', 'Appendix 1: Data Collection', 'Appendix 2: Further Research Supporting HP3', 'Appendix 3: History and Character Attractions in the Parish', 'Appendix 4: Sites of Special Interest', 'Appendix 5: Areas of Influence Connected to the Parish', 'Parking', 'Flood Defenses', 'Visitor Accommodation', 'Local Economy']}, ['SETTING THE SCENE', 'Introduction', 'Format of the Neighbourhood Development Plan', 'National and local planning policy context', 'ABBERLEY NEIGHBOURHOOD AREA', 'The community of Abberley', 'Environment', 'Economy', 'Key issues', 'VISION AND OBJECTIVES', 'Vision', 'Objectives', 'Objectives for the community', 'Objectives for the natural environment', 'Objectives for the built environment', 'Objectives for the economy', 'SUSTAINABLE DEVELOPMENT', 'SOCIAL AND COMMUNITY', 'Type of new housing', 'Criteria for development of Land at The Orchard'], ['Introduction', 'National and local strategic planning policy context', 'Walsham le Willows Parish', 'How the Plan was prepared', 'Vision, objectives and policies', 'Built Environment and Design', 'Housing', 'Community and Infrastructure', 'Transport and Accessibility', 'Natural and Historic Environment', 'Economy', 'Projects and Community Infrastructure Levy (CIL) funding', 'Implementation and monitoring', 'Local Green Space justification', 'Non-designated Heritage Assets justification', 'Glossary', 'Housing Needs Assessment', 'Design Guidance and Codes', 'Built Environment and Design Policies', 'Housing Policies'], ['Foreword', 'Introduction', 'The Neighbourhood Area', 'Policy Context', 'Summary of Opportunities', 'Vision and Objectives', 'Policies', 'Natural and Built Heritage Policies', 'Character and Design Policies', 'Housing Policies', 'Community Facilities and Green Space Policies', 'Retail and Business Policies', 'Highways and Traffic Policies', 'Implementation', 'List of Appendices', 'List of Figures', 'Neighbourhood Plans form part of the planning system', 'About this Document', 'About Neighbourhood Plans', 'Neighbourhood Plan Preparation Process'], ['Addingham', 'Neighbourhood', 'Development Plan', 'Vision Statement', 'Contents', 'Foreword', 'Introduction', 'Key Issues', 'Vision and Objectives', 'City of Bradford Metropolitan District', 'Strategic Planning Policy', 'Policies and Proposals', 'Housing Needs', 'Natural Environment', 'Climate Change', 'Business and Employment', 'Transport, Traffic and Parking', 'Local Green Spaces', 'Protecting and Enhancing Recreation Facilities', 'Green Infrastructure', 'Responding to Climate C ...
