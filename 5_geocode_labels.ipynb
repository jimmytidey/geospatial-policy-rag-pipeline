# %%
from data_pipeline.geocode_geo_labels.geocode_extract import extract_chunks_for_geocoding, count_chunks_for_geocoding
from data_pipeline.geocode_geo_labels.geocode_transform import geocode_row
count = count_chunks_for_geocoding()
print("Total chunks ungeocoded: " + str(count))

records  = extract_chunks_for_geocoding(10)

if records is not None:
    for index, record in enumerate(records):
        print(record)
        results = geocode_row(record)
        print(results)
            
else:
    print("No records found.")
# Out:
# Total chunks ungeocoded: [[5096]]
# ['a16149690a9a5fb2ca023f35747e1939', '32f6707594fef4f28568218dd8862085', ' 23 ', 'MORLEY > TROY HILL > Schofield', ['Morley', 'Troy Hill', 'Schofield'], ['no_label'], 'MORLEY > TROY HILL > Schofield  23 ', 3, 849, 63, 'sherpa', '', '', '[-0.011050819,0.010819907,0.008392026,0.0007978857,-0.014686045,0.04845207,0.0007999474,-0.022246785,0.0013252737,-0.019066786,0.025044126,0.013412726,-0.0052516134,-0.017852847,-0.00832605,-0.021098819,0.006416073,-0.013564469,-0.002368504,-0.0066469857,-0.008939618,0.02313085,-0.0058486876,-0.01564928,0.0091045555,0.013254386,0.0333042,-0.024582302,0.0075475452,0.0010250872,0.02239193,-0.0040013865,-0.005307692,-0.01652015,-0.034175072,-0.024080891,0.0068350146,-0.02939848,-0.01128833,0.0026307548,0.005149352,-0.033832002,0.010226131,-0.01646737,-0.035758473,0.0008238634,0.023830187,-0.03153607,-0.042567097,0.021217573,0.025743462,-0.004499498,-0.006696467,-0.016784051,0.022853754,0.0044236267,0.018367453,0.039479464,-0.0037440837,-0.009368456,-0.01425061,-0.015873594,-0.03230138,0.013788784,0.0163882,-0.012172395,-0.01142028,-0.011433475,-0.010034804,-0.0072638523,0.025571927,0.01657293,-0.0020188363,-0.010681359,0.01828828,-0.014527705,-0.010179949,0.01181613,0.016981976,-0.0036682126,0.029134579,-0.02336836,-0.023988526,0.0074617774,0.026746282,-0.0021013052,0.02926653,0.017852847,0.014738825,-0.0026901325,0.0118359225,0.038951665,0.016797246,0.0013698068,-0.016863221,0.01221198,-0.012047043,0.038186353,0.011532438,-0.02781508,0.0005133683,-0.020280728,-0.0034702874,-0.014290195,-0.038898885,-0.002977124,0.0018868863,-0.0022316058,0.010272314,-0.03026935,-0.00208811,0.009579577,0.009474016,-0.012014056,-0.018169526,0.00067005906,-0.006508438,0.003201439,-0.018486207,-0.01223837,0.015213845,0.0058124014,0.010298704,-0.015820814,0.026917819,-0.027128939,-0.0049151406,-0.01448812,0.02784147,0.017681312,0.05716078,-0.0056375675,0.009434431,0.008867046,-0.0052516134,0.009533393,-0.022589855,0.022167614,-0.016506955,-0.01831467,-0.0028451737,0.011090404,-0.012053641,-0.022325955,0.0024806615,0.01514787,0.005433045,0.012442893,-0.019462638,0.0033729742,0.019528612,-0.026746282,0.000315237,-0.0027495099,-0.001289812,-0.006521633,-0.005020701,0.014791605,-0.0174438,0.0018456519,0.006577712,-0.008998996,0.015556916,-0.0029919683,-0.012878329,0.021798154,0.020557823,0.026469188,-0.0018868863,0.005043792,-0.0016526749,0.006109289,-0.03211665,0.017707702,-0.0046149543,0.009856671,0.004222403,-0.015952764,-0.019264713,-0.019884879,-0.015609696,-0.0054099537,0.0415115,0.037684944,0.0013302218,0.026258068,0.022128029,-0.0060466127,-0.013604054,-0.012687001,0.005980638,0.02897624,0.001863795,0.009737916,-0.6532057,-0.013260984,-0.018525792,0.0076069226,0.015899984,0.009064971,-0.0042883777,-0.0059872353,-0.0099160485,-0.0030051633,-0.015161065,0.02072936,-0.0060796,-0.0045852656,-0.018380648,-0.0145409,0.012752976,-0.013538079,0.02323641,-0.004443419,-0.02894985,0.004196013,0.0049580242,-0.017668117,0.013096047,-0.0129311085,0.0069933548,-0.027076159,-0.0050239996,0.003846345,-0.019053591,0.02434479,0.0037110962,0.0005339855,0.03261806,0.002566429,-0.009579577,0.03438619,-0.0022052159,0.020241143,-0.0123637235,-0.02228637,0.015398576,-0.00020163623,-0.020227948,0.02792064,0.0061026914,-0.02950404,-0.02183774,-0.03306669,0.016427785,-0.0029985658,-0.012832146,-0.0034867811,0.0065810108,-0.010067792,0.035679303,-0.019673757,0.0025021036,-0.019489028,-0.040851746,0.0072374623,-0.0104306545,-0.0049151406,-0.0014761916,0.0012931109,-0.018024381,0.01425061,0.008048955,-0.0036055362,0.0058882725,0.010193144,-0.0145540945,-0.0007249008,-0.00814132,0.0095927715,0.011750155,-0.014448535,-0.0056012813,0.015055506,0.009500406,0.0066766744,0.011453267,-0.019924464,0.03269723,-0.013564469,-0.014263805,0.018037576,0.0077454704,0.0044533154,0.011901898,0.0032047378,0.026482383,-0.0016403046,0.015266625,-0.0055056172,-0.018116746,0.017800067,0.016981976,-0.041749008,-0.0003985305,-0.018578572,0.00404427,-0.00790381,-0.0194 ...
# Error converting geometry: ParseException: Unknown type: '...'
# Raw geometry: 0103000020E61000000100000012000000F6C052534E20F9BFBD370FF27DE44A40FF3AB133F79BF9BFF1D1821A35E44A4021...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 11
#       9     for index, record in enumerate(records):
#      10         print(record)
# ---> 11         results = geocode_row(record)
#      12         print(results)
#      14 else:
#
# File ~/Projects/geospatial-policy-rag-pipeline/data_pipeline/geocode_geo_labels/geocode_transform.py:11, in geocode_row(row)
#       9 results = []
#      10 for label in row['openai_geo_labels']:
# ---> 11     best_location =geolocate_label(label, row)
#      12     results.append(best_location)
#      14 return results
#
# File ~/Projects/geospatial-policy-rag-pipeline/data_pipeline/geocode_geo_labels/geocode_transform.py:17, in geolocate_label(label, row)
#      16 def geolocate_label(label, row):
# ---> 17     geom = get_geometry(row)
#      19     if not geom:
#      20         print("No bounding polygon or center point found, skipping geocode")
#
# File ~/Projects/geospatial-policy-rag-pipeline/data_pipeline/geocode_geo_labels/geocode_transform.py:96, in get_geometry(row)
#      93 else:
#      94        geom = None
# ---> 96 return geom
#
# UnboundLocalError: cannot access local variable 'geom' where it is not associated with a value
